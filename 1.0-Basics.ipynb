# %%
print(1+1)
# Out:
# 2

# %%
! pip install pandas

# %%
import numpy as np
import pandas as pd
np.sum([1,2],dtype=np.float16)
pd.Series([1,2,3,4,5,6],index = ['a','b','c','d','e','f'],dtype = np.complex64)
# np.power(3,4)
# np.pow(3,4)
# Out:
# a    1.0+0.0j
# b    2.0+0.0j
# c    3.0+0.0j
# d    4.0+0.0j
# e    5.0+0.0j
# f    6.0+0.0j
# dtype: complex64

# %%
print(394+2)
# Out:
# 396

# %%
name = 'prabir'
name  = 'kayal'
print(name)

##indentation

age = 30
print(age)if age>13 else NONE
# Out:
# kayal
# 30

# %%
# line continuation
total =3+4+5+6+7+8+9+10+\
12+23+44

print(total)
# Out:
# 131

# %%
# Multiple statements in a single line
x = 4; y = 5; z = 6; total = x+y+z; print(total)
# Out:
# 15

# %%
def test(x,y):
  try:
    return x/y
  except ZeroDivisionError:
    return f'check the denominator'
    

if __name__ == '__main__':
  print(test(12,4))
  print(test(12,0))
# Out:
# 3.0
# check the denominator

# %%
age = 50
if True:
  print('age is greater than 13')
  if False:
    print('age is greater than 18')
    print('age is greater than 30')
else:
  print('age is less than 30')
# Out:
# age is greater than 13
