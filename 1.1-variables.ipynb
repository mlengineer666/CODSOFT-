# %%
# invalid variable name
-ga = 3
print(-ga)
# Out:
#   Cell In[2], line 1
#     -ga = 3
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# invalid variable name
@sjs = 334
print(@sjs)
# Out:
#   Cell In[1], line 1
#     @sjs = 334
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# python is dynamically  typed of variable determined at runtime
age = 23 #int
height= 5.8  #float
name = "John"  #string
is_student = True #boolean

print(type(name))
# Out:
# <class 'str'>

# %%
# Dynamic typing
# python allows the type of a variable to change during runtime

var = 10
print(var,type(var))


var = 10.11
print(var,type(var))


var = "sandi"
print(var,type(var))
# Out:
# 10 <class 'int'>
# 10.11 <class 'float'>
# sandi <class 'str'>

# %%
# input by default is string

age = input("enter the age:...")
print(age,type(age))
# Out:
# 26 <class 'str'>

# %%
# simple calculator

num1 = float(input("enter the first number:..."))
num2 = float(input("enter the second number:..."))

sum = num1 + num2
diff = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("sum:",sum)
print("difference:",diff)
print("product:",product)
print("quotient:",quotient)
# Out:
# sum: 17.4
# difference: -9.200000000000001
# product: 54.53
# quotient: 0.3082706766917293
