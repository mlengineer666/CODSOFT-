# %%
# Integer
age = 23
print(age, type(age))
# Out:
# 23 <class 'int'>

# %%
# float
height = 5.8
print(height, type(height))
# Out:
# 5.8 <class 'float'>

# %%
# string
name = "John"
print(name, type(name))
# Out:
# John <class 'str'>

# %%
# boolean
is_student = True

# %%
a = b = 10
type(a==b)
# Out:
# bool

# %%
# common errors
result = "Hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # common errors
# ----> 2 result = "Hello" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
# type casting
result = "Hello " + str(5)
print(result.center(20, "*"))
# Out:
# ******Hello 5*******

# %%
str = "Hello World"
# Out:
# <method-wrapper '__delattr__' of str object at 0x0000028638D79C70>
