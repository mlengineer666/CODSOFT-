# %% [markdown]
# comparision operator

# %%
a = 10
b = 5

addition = a + b
subtraction = a - b
multiplication = a * b
division = a / b
floor_division = a // b
modulus = a % b
exponentiation = a ** b


print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Floor Division:", floor_division)
print("Modulus:", modulus)
print("Exponentiation:", exponentiation)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# Floor Division: 2
# Modulus: 0
# Exponentiation: 100000

# %%
str1 = "Hello"
str2 = "Hello"

str1 == str2
# Out:
# True

# %%
# Not equal to
str1 != str2

str3 = "World"
str4 = "world"
str3 == str4
# Out:
# False

# %%
# greater than and less than
num1 = 45
num2 = 55

num1 > num2
num1 < num2
# Out:
# True

# %%
# greater than or equal to
print(num1 >= num2)
# less than or equal to
print(num1 <= num2)
# Out:
# False
# True

# %% [markdown]
# Logical Operator

# %%
# AND, OR, NOT

X= True
Y = False
result = X and Y
print("AND of X and Y:", result)
# Out:
# AND of X and Y: False

# %%
a =2
b = 4
a&b
a and b # Rule of and: returns first False value or last value if all are True
# Out:
# 4
