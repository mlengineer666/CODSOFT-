# %% [markdown]
# how to multiply string element within a array

# %%
import numpy as np

my_arr = np.array(['John','Alex','Guido','James'])
my_arr
# Out:
# array(['John', 'Alex', 'Guido', 'James'], dtype='<U5')

# %%
np.char.multiply(my_arr,3)  # it takes 2 things one is array and second is how many times to multiply
# Out:
# array(['JohnJohnJohn', 'AlexAlexAlex', 'GuidoGuidoGuido',
#        'JamesJamesJames'], dtype='<U15')
