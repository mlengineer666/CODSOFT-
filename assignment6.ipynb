# %%
import numpy as np
sets = set(np.arange(1,11))
print(sets)
# Out:
# {np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10)}

# %%
sets.add(11)
# sets.remove(1) already removed
sets
# Out:
# {np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  11}
