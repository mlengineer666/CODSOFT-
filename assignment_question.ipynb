# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here

age = input('Enter your age: ..')
print('Your age is: ' + age)
# Out:
# Your age is: 5

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here

num = int(input('Enter a number:..'))
if num > 0:
  print('The number is positive')
elif num < 0:
  print('The number is negative')
else:
  print('The number is zero')
# Out:
# The number is positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here

num1 = int(input('Enter first number:..'))
num2 = int(input('Enter second number:..'))
num3 = int(input('Enter third number:..'))

if num1 > num2 and num1 > num3:
  print('The largest number is num1: ', (num1))
elif num2 > num1 and num2 > num3:
  print('The largest number is num2: ', (num2))
else:
  print('The largest number is num3: ', (num3))
# Out:
# The largest number is num2:  56

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
res = 1
for i in range(1, 6):
  res *= i
print(res)


# recursive function to calculate factorial of a number
def factorial(n,product):
  if n == 0 or n == 1:
    return product
  return factorial(n-1, product * n)

num = int(input('Enter the number.. '))
factorial(num,1)
# Out:
# 120
# 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
num = print(int(True))
num = print(str(False))
num = print(float(True))
num = print(bool(False))
# Out:
# 1
# False
# 1.0
# False

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here

# using third variables
a = 10
b = 20
c = a+b
a = c - a
b = c - b
print('The value of a is: ', a)
print('The value of b is: ', b)

# without using third variable
a = 10
b = 20
a = a+b
b = a - b
a = a - b
print('The value of a is: ', a)
print('The value of b is: ', b)

# using XOR operator
a = 10  
b = 20
a = a ^ b
b =a^b
a =a^b
print(f'value swapped',a,b)
# Out:
# The value of a is:  20
# The value of b is:  10
# The value of a is:  20
# The value of b is:  10
# value swapped 20 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
num = int(input('Enter a number:..'))

celsius = (num - 32) * 5/9
print('The temperature in Celsius is: ', celsius)

fahrenheit = (celsius * 9/5) + 32
print('The temperature in Fahrenheit is: ', fahrenheit)
# Out:
# The temperature in Celsius is:  1.1111111111111112
# The temperature in Fahrenheit is:  34.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = input('Enter first string:..')
str2 = input('Enter second string:..')

print('The concatenated string is: ', str1 +  str2)
# Out:
# The concatenated string is:  Hello World

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
num = int(input('Enter a number:..'))
if isinstance(num,int):
  print('The number is an integer')
else:
  print('The number is not an integer')
# Out:
# The number is an integer

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
num1 = int(input('Enter a number:..'))
num2 = int(input('Enter a number:..'))
result = num1 + num2
print('The sum of the two numbers is: ', result)
result = num1 - num2
print('The difference of the two numbers is: ', result)
result = num1 * num2
print('The product of the two numbers is: ', result)
result = num1 / num2
print('The quotient of the two numbers is: ', result)
# Out:
# The sum of the two numbers is:  110
# The difference of the two numbers is:  -20
# The product of the two numbers is:  2925
# The quotient of the two numbers is:  0.6923076923076923

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here

num1 = int(input('Enter a number:..'))
num2 = int(input('Enter a number:..'))


if num1 != num2:
  print('The first number is not equal to the second number')

if num1 == num2:
  print('The first number is equal to the second number')
  
if num1 > num2:
  print('The first number is greater than the second number')

if num1 < num2:
  print('The first number is less than the second number')
# Out:
# The first number is not equal to the second number
# The first number is greater than the second number

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
num1 = int(input('Enter a number:..'))
num2 = int(input('Enter a number:..'))


if num1 and num2:
  print('If all true then the result is true')

if num1 or num2:
  print('If any one is true then the result is true')

if not num1:
  print('If num1 is false then the result is true')

if not num2:
  print('If num2 is false then the result is true')
# Out:
# If all true then the result is true
# If any one is true then the result is true

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num1 = int(input('Enter a number:..'))
num2 = int(input('Enter a number:..'))

result = num1 ** num2
print('The result of num1 raised to the power of num2 is: ', result)
# Out:
# The result of num1 raised to the power of num2 is:  243

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
def even_odd(num):
  return 'Even' if num%2==0 else 'Odd'

even_odd_num = int(input('Enter a number:..'))
print('The number is: ', even_odd(even_odd_num))
# Out:
# The number is:  Even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

# first approach
# result = 0
# num = int(input('Enter a number:..'))
# for i in range(num):
#   result += i
# print('The sum of all numbers from 0 to num is: ', result)

# second approach
number = int(input('Enter the number'))
total = (number*(number+1))//2
print(total)
# Out:
# 55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
def is_leap_year(year):
  return year if year%4==0 and (year%100!=0 or year%400==0) else 'Not a leap year'

is_leap_year(year=int(input('Enter a year:..')))
# Out:
# 'Not a leap year'

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str1 = input("Enter a string..")
str1[::-1]

for i in range(len(str1)-1,-1,-1):
  print(str1[i],end=' ')
# Out:
# o l a v i a b o s a r m a

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
str1 = (input('Enter a string:..'))
# if str1 == str1[::-1]:
#   print('The string is a palindrome')
# else: 
#   print('The string is not a palindrome')

''' using 2 pointers '''

# left = 0
# right = len(str1) - 1

# while left < right:
#   if str1[left] != str1[right]:
#     print('The string is not a palindrome')
#     break
#   left+=1
#   right-=1
# else:  print('The string is a palindrome')

str1 == ''.join(reversed(str1))
# Out:
# False

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
numbers1 = []
for i in range(5):
  num = int(input('Enter a number:..'))
  numbers1.append(num)

numbers1.sort()
print('The sorted list is: ', numbers1)
# Out:
# The sorted list is:  [3, 4, 6, 7, 8]
